# %% [markdown]
# # Source Fabric Prediction System

# %%
# required libraries
import pandas as pd # data processing, CSV file I/O
import pickle # for saving and loading models

# %%
input = pd.read_csv('input/test.csv')
input
# Out:
#    Item_Id  Item_Visibility  Store_Id  Item_Fit_Type  Item_Fabric  \
# 0       56         0.072882         8              1            7
# 1      747         0.111937         0              1            9
# 2      995         0.048687         8              1           13
# 3     1391         0.011937         5              2           15
# 4      442         0.090185         2              0           15
# 5      845         0.068754         5              2           12
# 6     1259         0.076475         2              2           14
#
#    Item_Fabric_Amount  Item_MRP  Store_Establishment_Year  Store_Size  \
# 0               11.50  140.2496                      1997           2
# 1               14.10  193.8452                      1998           2
# 2               10.65   99.8042                      1997           2
# 3               20.25  169.8106                      1985           1
# 4               14.10  192.1846                      2007           2
# 5                9.00   56.3614                      1985           1
# 6               12.65  110.2886                      2007           2
#
#    Store_Location_Type  Store_Type
# 0                    0           1
# 1                    2           0
# 2                    0           1
# 3                    2           3
# 4                    1           1
# 5                    2           3
# 6                    1           1

# %%
regressor_randomForest = pickle.load(open('models/model_randomForest.pkl', "rb"))
predicitons = regressor_randomForest.predict(input)

# %%
predictions_df = pd.DataFrame(predicitons, columns=['Prediction']) # transform predictions to dataframe
result = input.copy()
result['Sales_Prediction'] = predictions_df['Prediction'].values # add prediction to result
result['Required_Fabric_Prediction'] = predictions_df['Prediction'].values * input['Item_Fabric_Amount'] # calculate required fabric amount
result
# Out:
#    Item_Id  Item_Visibility  Store_Id  Item_Fit_Type  Item_Fabric  \
# 0       56         0.072882         8              1            7
# 1      747         0.111937         0              1            9
# 2      995         0.048687         8              1           13
# 3     1391         0.011937         5              2           15
# 4      442         0.090185         2              0           15
# 5      845         0.068754         5              2           12
# 6     1259         0.076475         2              2           14
#
#    Item_Fabric_Amount  Item_MRP  Store_Establishment_Year  Store_Size  \
# 0               11.50  140.2496                      1997           2
# 1               14.10  193.8452                      1998           2
# 2               10.65   99.8042                      1997           2
# 3               20.25  169.8106                      1985           1
# 4               14.10  192.1846                      2007           2
# 5                9.00   56.3614                      1985           1
# 6               12.65  110.2886                      2007           2
#
#    Store_Location_Type  Store_Type  Sales_Prediction  \
# 0                    0           1      2.039924e+06
# 1                    2           0      7.938804e+05
# 2                    0           1      3.388920e+05
# 3                    2           3      7.885427e+05
# 4                    1           1      3.693378e+05
# 5                    2           3      7.509191e+05
# 6                    1           1      1.244434e+05
#
#    Required_Fabric_Prediction
# 0                2.345913e+07
# 1                1.119371e+07
# 2                3.609200e+06
# 3                1.596799e+07
# 4                5.207663e+06
# 5                6.758272e+06
# 6                1.574209e+06
