# %% [markdown]
# ## Data Collection

# %%
# required libraries
import numpy as np # data conversion
import pandas as pd # data processing, CSV file I/O
import os # accessing directory structure

# %%
# Monitoring input files
print(os.listdir('../dataset'))
# Out:
# ['Stores.csv', 'Item_Store_Sales.csv', 'Items.csv']

# %%
data_Item_Store_Sale = pd.read_csv('../dataset/Item_Store_Sales.csv')
data_Item_Store_Sale
# Out:
#      Item_Id  Item_Visibility Store_Id  Item_Store_Sales
# 0      TSH15         0.016047   STR049      3.735138e+06
# 1      SHR01         0.019278   STR018      4.434228e+02
# 2      BLS15         0.016760   STR049      2.097270e+03
# 3      SWT07         0.000000   STR010      7.323800e+02
# 4      CRD19         0.000000   STR013      9.947052e+02
# ...      ...              ...      ...               ...
# 8518   BJK22         0.056783   STR013      2.778383e+03
# 8519   PRK36         0.046982   STR045      5.492850e+05
# 8520   NCJ29         0.035186   STR035      1.193114e+03
# 8521   BLS46         0.145221   STR018      1.845598e+03
# 8522   DRG01         0.044878   STR046      7.656700e+02
#
# [8523 rows x 4 columns]

# %%
data_Stores = pd.read_csv('../dataset/Stores.csv')
data_Stores
# Out:
#   Store_Id  Store_Establishment_Year Store_Size Store_Location_Type  \
# 0   STR049                      1999     Medium            Region 1
# 1   STR018                      2009     Medium            Region 3
# 2   STR010                      1998        NaN            Region 3
# 3   STR013                      1987       High            Region 3
# 4   STR027                      1985     Medium            Region 3
# 5   STR045                      2002        NaN            Region 2
# 6   STR017                      2007        NaN            Region 2
# 7   STR046                      1997      Small            Region 1
# 8   STR035                      2004      Small            Region 2
# 9   STR019                      1985      Small            Region 1
#
#     Store_Type
# 0   Mall Type1
# 1   Mall Type2
# 2  Local Store
# 3   Mall Type1
# 4   Mall Type3
# 5   Mall Type1
# 6   Mall Type1
# 7   Mall Type1
# 8   Mall Type1
# 9  Local Store

# %%
data_Items = pd.read_csv('../dataset/Items.csv')
data_Items
# Out:
#      Item_Id Item_Fit_Type Item_Fabric  Item_Fabric_Amount     Item_MRP
# 0      TSH15      Oversize       Linen                9.30     249.8092
# 1      SHR01       Regular    Cashmere                5.92      48.2692
# 2      BLS15      Oversize     Chiffon               17.50  141618.0000
# 3      FDX07       Regular        Lace               19.20  182095.0000
# 4      CRD19      Oversize       Denim                8.93      53.8614
# ...      ...           ...         ...                 ...          ...
# 1554   FDD28      Oversize      Velvet            10695.00     244.4486
# 1555   TCT43       Regular        Lace                 NaN     188.4898
# 1556   NCF55         Basic       Denim             6675.00     120.9756
# 1557   NCW30      Oversize       Denim                5.21     121.9414
# 1558   NCW05      Oversize       Crepe               20.25     160.3578
#
# [1559 rows x 5 columns]

# %%
# merge relational datasets
data_frame = pd.merge(data_Item_Store_Sale, data_Items, on='Item_Id')
data_frame = pd.merge(data_frame, data_Stores, on='Store_Id')
data_frame
# Out:
#      Item_Id  Item_Visibility Store_Id  Item_Store_Sales Item_Fit_Type  \
# 0      TSH15         0.016047   STR049      3.735138e+06      Oversize
# 1      SHR01         0.019278   STR018      4.434228e+02       Regular
# 2      BLS15         0.016760   STR049      2.097270e+03      Oversize
# 3      CRD19         0.000000   STR013      9.947052e+02      Oversize
# 4      JCK36         0.000000   STR018      5.566088e+02       Regular
# ...      ...              ...      ...               ...           ...
# 8155   BJK22         0.056783   STR013      2.778383e+03      Oversize
# 8156   PRK36         0.046982   STR045      5.492850e+05       Regular
# 8157   NCJ29         0.035186   STR035      1.193114e+03      Oversize
# 8158   BLS46         0.145221   STR018      1.845598e+03       Regular
# 8159   DRG01         0.044878   STR046      7.656700e+02      Oversize
#
#      Item_Fabric  Item_Fabric_Amount     Item_MRP  Store_Establishment_Year  \
# ...

# %% [markdown]
# # Data Exploration

# %%
data_frame.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8160 entries, 0 to 8159
# Data columns (total 12 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Item_Id                   8160 non-null   object
#  1   Item_Visibility           8160 non-null   float64
#  2   Store_Id                  8160 non-null   object
#  3   Item_Store_Sales          8160 non-null   float64
#  4   Item_Fit_Type             8160 non-null   object
#  5   Item_Fabric               8160 non-null   object
#  6   Item_Fabric_Amount        6829 non-null   float64
#  7   Item_MRP                  8160 non-null   float64
#  8   Store_Establishment_Year  8160 non-null   int64
#  9   Store_Size                5853 non-null   object
#  10  Store_Location_Type       8160 non-null   object
#  11  Store_Type                8160 non-null   object
# dtypes: float64(4), int64(1), object(7)
# memory usage: 765.1+ KB

# %%
data_frame.describe()
# Out:
#        Item_Visibility  Item_Store_Sales  Item_Fabric_Amount       Item_MRP  \
# count      8160.000000      8.160000e+03         6829.000000    8160.000000
# mean          0.066078      6.646664e+05         1279.873242   25467.096589
# std           0.051910      1.372690e+06         2958.445763   58020.548755
# min           0.000000      3.329000e+01            4.610000      31.290000
# 25%           0.026892      1.191283e+03           11.300000     101.901600
# 50%           0.053730      2.850623e+03           15.500000     163.123600
# 75%           0.094251      6.391680e+05           19.600000     239.653800
# max           0.328391      1.144510e+07        11395.000000  264791.000000
#
#        Store_Establishment_Year
# count               8160.000000
# mean                1997.830025
# std                    8.372218
# min                 1985.000000
# 25%                 1987.000000
# 50%                 1999.000000
# 75%                 2004.000000
# ...

# %% [markdown]
# ## Data Visualization
# Data visualization is an essential tool for representing data in a more accessible, understandable and effective way. Visual analysis makes it easier to spot unexpected data patterns or interesting connections.

# %%
# required libraries
import matplotlib.pyplot as plt # plotting
import seaborn as sns
sns.set()

# %%
# Item_Store_Sales distribution
sns.distplot(data_frame['Item_Store_Sales'])
plt.savefig('figures/Item_Store_Sales')
plt.show()

# # Item_Store_Sales distribution
# plt.figure(figsize=(8, 6))
# sns.histplot(data_frame['Item_Store_Sales'], kde=True)  # Using histplot instead of distplot
# plt.title('Item_Store_Sales Distribution', fontsize=14)
# plt.xlabel('Item_Store_Sales', fontsize=12)
# plt.ylabel('Density', fontsize=12)
# plt.savefig('figures/Item_Store_Sales')
# plt.show()
# Out:
# /tmp/ipykernel_4745/2695407629.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data_frame['Item_Store_Sales'])

# %%
# Item Visibility distribution
plt.figure(figsize=(8, 6))
sns.histplot(data_frame['Item_Visibility'], kde=True)  # Using histplot instead of distplot
plt.title('Item Visibility Distribution', fontsize=14)
plt.xlabel('Item Visibility', fontsize=12)
plt.ylabel('Density', fontsize=12)
plt.savefig('figures/Item_Visibility')
plt.show()

# %%
# Store_Establishment_Year column
sns.countplot(x='Store_Establishment_Year', data=data_frame)
plt.savefig('figures/Store_Establishment_Year')
plt.show()

# %%
# data_frame.groupby('Store_Size').mean()

numeric_columns = data_frame.select_dtypes(include='number')
grouped_data = data_frame.groupby('Store_Size')[numeric_columns.columns].mean()
grouped_data
# Out:
#             Item_Visibility  Item_Store_Sales  Item_Fabric_Amount  \
# Store_Size
# High               0.060020     641548.377087         1197.174973
# Medium             0.059998     860670.596272         1228.543783
# Small              0.071424     555880.529613         1331.151285
#
#                 Item_MRP  Store_Establishment_Year
# Store_Size
# High        26014.137750               1987.000000
# Medium      25724.930784               1997.621127
# Small       24905.397879               1997.079860

# %%
# Store_Size column
sns.countplot(x='Store_Size', data=data_frame)
plt.savefig('figures/Store_Size')
plt.show()

# %%
numeric_columns = data_frame.select_dtypes(include='number')
grouped_data = data_frame.groupby('Item_Fit_Type')[numeric_columns.columns].mean()
grouped_data
# Out:
#                Item_Visibility  Item_Store_Sales  Item_Fabric_Amount  \
# Item_Fit_Type
# Basic                 0.073309     419466.590278         1780.258876
# Oversize              0.063624     679466.504842         1257.318978
# Regular               0.069368     676920.022207         1255.816644
# Slim Fit              0.075266     332746.258377         1521.005728
#
#                    Item_MRP  Store_Establishment_Year
# Item_Fit_Type
# Basic          19892.894144               1997.833333
# Oversize       25276.761944               1997.792018
# Regular        26795.791120               1997.888127
# Slim Fit       15170.559915               1998.097087

# %%
# Item_Fit_Type column
sns.countplot(x='Item_Fit_Type', data=data_frame)
plt.savefig('figures/Item_Fit_Type')
plt.show()

# %%
numeric_columns = data_frame.select_dtypes(include='number')
grouped_data = data_frame.groupby('Item_Fabric')[numeric_columns.columns].mean()
grouped_data
# Out:
#              Item_Visibility  Item_Store_Sales  Item_Fabric_Amount  \
# Item_Fabric
# Cashmere            0.063493      6.105237e+05         1029.025971
# Chiffon             0.061222      6.550125e+05         1313.401513
# Cotton              0.069007      6.400170e+05         1591.246886
# Crepe               0.055216      5.754900e+05         1174.260442
# Denim               0.061322      7.187326e+05         1056.695118
# Jacquard            0.074976      5.425397e+05         1786.483902
# Jersey              0.067564      7.509200e+05         1005.367266
# Lace                0.069285      6.229555e+05          967.470280
# Linen               0.072394      6.462989e+05         1363.818726
# Organza             0.066331      7.029405e+05         1203.264434
# Polyester           0.067193      5.926042e+05          828.699337
# Satin               0.065799      7.059559e+05         2081.484410
# Silk                0.085723      5.647851e+05         2666.689036
# ...

# %%
# Item_Fabric column
plt.figure(figsize=(30,6)) # for monitoring 15 parameters
sns.countplot(x='Item_Fabric', data=data_frame)
plt.savefig('figures/Item_Fabric')
plt.show()

# %% [markdown]
# # Data Preprocessing
# In the data preprocessing step, we clarify the data types of the columns we need and take care that the data is very clean and not missing values.

# %% [markdown]
# ## Data Manipulation

# %%
data_frame.isnull().sum() # Is there any null value?
# Out:
# Item_Id                        0
# Item_Visibility                0
# Store_Id                       0
# Item_Store_Sales               0
# Item_Fit_Type                  0
# Item_Fabric                    0
# Item_Fabric_Amount          1331
# Item_MRP                       0
# Store_Establishment_Year       0
# Store_Size                  2307
# Store_Location_Type            0
# Store_Type                     0
# dtype: int64

# %% [markdown]
# Item_Fabric_Amount

# %%
data_frame['Item_Fabric_Amount'] = data_frame['Item_Fabric_Amount'].fillna(data_frame['Item_Fabric_Amount'].mean())

# we filled the null variables with the mean so we don't affect the general mean

# %% [markdown]
# Store_Size

# %%
# Let's match the most common value in the "Store_Size" column for each unique "Store_Type" value
mode_of_store_size = data_frame.pivot_table(values='Store_Size', columns='Store_Type', aggfunc=lambda x: x.mode()[0])
mode_of_store_size
# Out:
# Store_Type Local Store Mall Type1 Mall Type2 Mall Type3
# Store_Size       Small      Small     Medium     Medium

# %%
miss_values = data_frame['Store_Size'].isnull()
miss_values.value_counts()
# Out:
# Store_Size
# False    5853
# True     2307
# Name: count, dtype: int64

# %%
data_frame.loc[miss_values, 'Store_Size'] = data_frame.loc[miss_values, 'Store_Type'].apply(lambda x: mode_of_store_size[x])
# Null values are replaced with the corresponding mode value for each "Store_Type" value. This ensures that missing data is properly completed.

# %% [markdown]
# ## Data Cleaning

# %%
data_frame.duplicated().sum() # Is there any duplicate data?
# Out:
# np.int64(0)

# %% [markdown]
# ## Data Conversion
# Machine learning algorithms generally work with numerical data. Numerical data generally requires less memory space and is more computationally efficient than categorical data. The best way to do this is to use LabelEncoder.

# %%
# required libraries
from sklearn.preprocessing import LabelEncoder
encoder = LabelEncoder()

# %%
data_frame['Store_Id'] = encoder.fit_transform(data_frame['Store_Id'])
data_frame['Store_Size'] = encoder.fit_transform(data_frame['Store_Size'])
data_frame['Store_Location_Type'] = encoder.fit_transform(data_frame['Store_Location_Type'])
data_frame['Store_Type'] = encoder.fit_transform(data_frame['Store_Type'])

data_frame['Item_Id'] = encoder.fit_transform(data_frame['Item_Id'])
data_frame['Item_Fit_Type'] = encoder.fit_transform(data_frame['Item_Fit_Type'])
data_frame['Item_Fabric'] = encoder.fit_transform(data_frame['Item_Fabric'])

# %%
# displaying label encoded dataset
data_frame
# Out:
#       Item_Id  Item_Visibility  Store_Id  Item_Store_Sales  Item_Fit_Type  \
# 0        1452         0.016047         9      3.735138e+06              1
# 1        1315         0.019278         3      4.434228e+02              2
# 2          46         0.016760         9      2.097270e+03              1
# 3         158         0.000000         1      9.947052e+02              1
# 4         836         0.000000         3      5.566088e+02              2
# ...       ...              ...       ...               ...            ...
# 8155       13         0.056783         1      2.778383e+03              1
# 8156     1295         0.046982         7      5.492850e+05              2
# 8157      987         0.035186         6      1.193114e+03              1
# 8158       65         0.145221         3      1.845598e+03              2
# 8159      207         0.044878         8      7.656700e+02              1
#
#       Item_Fabric  Item_Fabric_Amount     Item_MRP  Store_Establishment_Year  \
# ...

# %% [markdown]
# ## Data Splitting (Test and Train)
# We have to separate the data into features and target variable. We will then split the Data into training and test sets.

# %%
# required libraries
from sklearn.model_selection import train_test_split

# %%
X = data_frame.drop(columns='Item_Store_Sales', axis=1)
X.shape
# Out:
# (8160, 11)

# %%
Y = data_frame['Item_Store_Sales']
Y.shape
# Out:
# (8160,)

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=2)

# %%
X_train
# Out:
#       Item_Id  Item_Visibility  Store_Id  Item_Fit_Type  Item_Fabric  \
# 5769     1153         0.025932         1              1            4
# 7207     1338         0.045169         3              1            8
# 7318     1479         0.065023         9              1           15
# 2177      945         0.032016         6              1            4
# 963      1352         0.126359         6              1           15
# ...       ...              ...       ...            ...          ...
# 3606      103         0.040522         3              1            7
# 5704     1113         0.134394         0              1            4
# 6637     1292         0.216108         4              2            9
# 2575      764         0.042563         7              2           14
# 7336      793         0.085835         8              2           14
#
#       Item_Fabric_Amount     Item_MRP  Store_Establishment_Year  Store_Size  \
# ...

# %%
X_test
# Out:
#       Item_Id  Item_Visibility  Store_Id  Item_Fit_Type  Item_Fabric  \
# 7374     1152         0.077234         8              1            3
# 3955     1343         0.141793         8              0            6
# 7462        1         0.023877         4              1           14
# 5217      230         0.036000         9              1            0
# 6168      287         0.099275         9              1            9
# ...       ...              ...       ...            ...          ...
# 7797      434         0.115032         3              2           15
# 1161     1407         0.076657         1              2            9
# 7886      149         0.042154         3              2            1
# 5019      348         0.153930         7              1           15
# 6293      237         0.000000         9              1           11
#
#       Item_Fabric_Amount    Item_MRP  Store_Establishment_Year  Store_Size  \
# ...

# %%
Y_train
# Out:
# 5769    3.078659e+03
# 7207    2.175169e+03
# 7318    6.977584e+02
# 2177    1.922830e+03
# 963     1.334263e+03
#             ...
# 3606    5.552106e+03
# 5704    4.727180e+01
# 6637    3.542056e+02
# 2575    3.425541e+06
# 7336    7.883072e+02
# Name: Item_Store_Sales, Length: 6528, dtype: float64

# %%
Y_test
# Out:
# 7374    1.188453e+06
# 3955    1.159824e+03
# 7462    5.166608e+02
# 5217    1.624552e+02
# 6168    8.522240e+05
#             ...
# 7797    7.876414e+02
# 1161    1.697790e+05
# 7886    3.408896e+02
# 5019    2.648552e+03
# 6293    1.635871e+03
# Name: Item_Store_Sales, Length: 1632, dtype: float64

# %% [markdown]
# # Machine Learning Model Training

# %%
# common libraries
from sklearn import metrics # for modelling evaluation
import pickle # for saving and loading models

# %% [markdown]
# ### randomForest Regressor

# %%
# required libraries
from sklearn.ensemble import RandomForestRegressor
regressor_randomForest = RandomForestRegressor()

# %%
# Machine Learning Model Training
regressor_randomForest.fit(X_train, Y_train)
y_pred_randomForest = regressor_randomForest.predict(X_test)

# %%
# Model Evaluation
print("R-squared Score:", metrics.r2_score(Y_test, y_pred_randomForest))
# Out:
# R-squared Score: 0.00356917397277412

# %%
# Saving trained model
pickle.dump(regressor_randomForest, open('models/model_randomForest.pkl','wb'))
print("Saved model")
# Out:
# Saved model

# %% [markdown]
# ### XGBoost Regressor

# %%
# required libraries
from xgboost import XGBRegressor
regressor_xgboost = XGBRegressor()

# %%
# Machine Learning Model Training
regressor_xgboost.fit(X_train, Y_train)
y_pred_xgb = regressor_xgboost.predict(X_test)

# %%
# Model Evaluation : Metrics for Continuous Target Regression
print("R-squared Score:", metrics.r2_score(Y_test, y_pred_xgb))
# Out:
# R-squared Score: 0.014474201342197568

# %%
# Saving trained model
pickle.dump(regressor_xgboost, open('models/model_xgboost.pkl','wb'))
print("Saved model")
# Out:
# Saved model

# %% [markdown]
# ### DecisionTree Regressor

# %%
# required libraries
from sklearn.tree import DecisionTreeRegressor
regressor_decisionTree = DecisionTreeRegressor()

# %%
# Machine Learning Model Training
regressor_decisionTree.fit(X_train, Y_train)
y_pred_decisionTree = regressor_decisionTree.predict(X_test)

# %%
# Model Evaluation
print("R-squared Score:", metrics.r2_score(Y_test, y_pred_decisionTree))
# negative value is the result of an unsuccessful modeling
# Out:
# R-squared Score: -0.868591483020881

# %%
# Saving trained model
pickle.dump(regressor_decisionTree, open('models/model_decisionTree.pkl','wb'))
print("Saved model")
# Out:
# Saved model

# %% [markdown]
# ## Model Comparison

# %%
# Model Comparison with Heatmap
models = ['RandomForestRegressor', 'XGBRegressor', 'DecisionTreeRegressor']
r2_scores = [metrics.r2_score(Y_test, y_pred_xgb), metrics.r2_score(Y_test, y_pred_randomForest), metrics.r2_score(Y_test, y_pred_decisionTree)]

plt.figure(figsize=(9,6)) # for monitoring 3 parameters
sns.heatmap(np.array(r2_scores).reshape(1, -1), annot=True, cmap='Blues', yticklabels=True, cbar=True)
plt.xticks(ticks=np.arange(len(models))+0.5, labels=models)
plt.yticks([])
plt.title('Model Comparison - R-squared Score')
# Out:
# Text(0.5, 1.0, 'Model Comparison - R-squared Score')
